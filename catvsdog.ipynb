# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# Paths
train_dir = 'train/'

# Image preprocessing and augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)

# Model architecture
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=100,
    epochs=10,
    verbose=1
)

# Save the model after training
model.save('cats_and_dogs_classifier.h5')  # This saves the model to a file

print("Model saved to 'cats_and_dogs_classifier.h5'")
# Out:
# /Users/anton/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Found 25000 images belonging to 2 classes.
# /Users/anton/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# /Users/anton/Library/Python/3.9/lib/python/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 29s 276ms/step - accuracy: 0.5137 - loss: 0.7121
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 262ms/step - accuracy: 0.5203 - loss: 0.6939
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 261ms/step - accuracy: 0.5756 - loss: 0.6871
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 261ms/step - accuracy: 0.5273 - loss: 0.6894
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 265ms/step - accuracy: 0.5489 - loss: 0.6795
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 261ms/step - accuracy: 0.5887 - loss: 0.6687
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 262ms/step - accuracy: 0.5973 - loss: 0.6626
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 21s 214ms/step - accuracy: 0.6190 - loss: 0.6389
# Epoch 9/10
# 2024-10-01 13:15:34.725134: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:135: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(type, value, traceback)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 266ms/step - accuracy: 0.6495 - loss: 0.6241
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 263ms/step - accuracy: 0.7018 - loss: 0.5765
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to 'cats_and_dogs_classifier.h5'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = tf.keras.models.load_model('cats_and_dogs_classifier.h5')  # Replace with your model's path

# Load and preprocess the image
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(150, 150))  # Resize the image to the size the model expects
    img_array = image.img_to_array(img)  # Convert the image to a NumPy array
    img_array = np.expand_dims(img_array, axis=0)  # Add a batch dimension
    img_array /= 255.0  # Scale the pixel values to [0, 1]
    return img_array

# Function to predict whether the image is a cat or dog
def predict_image(img_path):
    img_array = preprocess_image(img_path)
    prediction = model.predict(img_array)  # Get the model's prediction
    confidence = float(prediction[0])  # Convert the NumPy array to a float

    if confidence > 0.5:
        print(f"This is a dog with {confidence * 100:.2f}% confidence.")
    else:
        print(f"This is a cat with {(1 - confidence) * 100:.2f}% confidence.")

# if True:
#     predict_image("/Users/anton/Downloads/download.jpeg")

if True:
    for i in range(1,1000):
        img_path = 'val_dir/' + str(i) + '.jpg'
        print("Running prediction for: " + img_path)
        predict_image(img_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Running prediction for: val_dir/1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# This is a dog with 54.07% confidence.
# Running prediction for: val_dir/2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 84.44% confidence.
# Running prediction for: val_dir/3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 61.94% confidence.
# Running prediction for: val_dir/4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# /var/folders/qf/k0gw0vm95gb6q7gc15m75n_r0000gn/T/ipykernel_29676/2897193550.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   confidence = float(prediction[0])  # Convert the NumPy array to a float
# This is a dog with 95.13% confidence.
# Running prediction for: val_dir/5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 52.49% confidence.
# Running prediction for: val_dir/6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 51.47% confidence.
# Running prediction for: val_dir/7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 78.46% confidence.
# Running prediction for: val_dir/8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 58.33% confidence.
# Running prediction for: val_dir/9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 68.72% confidence.
# Running prediction for: val_dir/10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# This is a cat with 60.92% confidence.
# Running prediction for: val_dir/11.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 73.92% confidence.
# Running prediction for: val_dir/12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 78.91% confidence.
# Running prediction for: val_dir/13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 72.27% confidence.
# Running prediction for: val_dir/14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 53.11% confidence.
# Running prediction for: val_dir/15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 65.57% confidence.
# Running prediction for: val_dir/16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 77.88% confidence.
# Running prediction for: val_dir/17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 78.06% confidence.
# Running prediction for: val_dir/18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a dog with 86.21% confidence.
# Running prediction for: val_dir/19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 57.18% confidence.
# Running prediction for: val_dir/20.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 55.88% confidence.
# Running prediction for: val_dir/21.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 63.24% confidence.
# Running prediction for: val_dir/22.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 57.17% confidence.
# Running prediction for: val_dir/23.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 62.93% confidence.
# Running prediction for: val_dir/24.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 75.46% confidence.
# Running prediction for: val_dir/25.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 86.38% confidence.
# Running prediction for: val_dir/26.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 69.74% confidence.
# Running prediction for: val_dir/27.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 65.14% confidence.
# Running prediction for: val_dir/28.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 82.32% confidence.
# Running prediction for: val_dir/29.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 71.89% confidence.
# Running prediction for: val_dir/30.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 60.89% confidence.
# Running prediction for: val_dir/31.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 77.05% confidence.
# Running prediction for: val_dir/32.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# This is a cat with 51.57% confidence.
# Running prediction for: val_dir/33.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 68.09% confidence.
# Running prediction for: val_dir/34.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 53.02% confidence.
# Running prediction for: val_dir/35.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 74.99% confidence.
# Running prediction for: val_dir/36.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 53.78% confidence.
# Running prediction for: val_dir/37.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 80.28% confidence.
# Running prediction for: val_dir/38.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a cat with 75.97% confidence.
# Running prediction for: val_dir/39.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 92.00% confidence.
# Running prediction for: val_dir/40.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 71.12% confidence.
# Running prediction for: val_dir/41.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 65.92% confidence.
# Running prediction for: val_dir/42.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 62.78% confidence.
# Running prediction for: val_dir/43.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# This is a dog with 68.90% confidence.
# Running prediction for: val_dir/44.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 74.42% confidence.
# Running prediction for: val_dir/45.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 57.00% confidence.
# Running prediction for: val_dir/46.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 78.57% confidence.
# Running prediction for: val_dir/47.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 67.27% confidence.
# Running prediction for: val_dir/48.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 96.60% confidence.
# Running prediction for: val_dir/49.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 69.89% confidence.
# Running prediction for: val_dir/50.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 61.45% confidence.
# Running prediction for: val_dir/51.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 55.31% confidence.
# Running prediction for: val_dir/52.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 55.80% confidence.
# Running prediction for: val_dir/53.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 70.55% confidence.
# Running prediction for: val_dir/54.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 58.82% confidence.
# Running prediction for: val_dir/55.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 54.54% confidence.
# Running prediction for: val_dir/56.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 56.28% confidence.
# Running prediction for: val_dir/57.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 88.13% confidence.
# Running prediction for: val_dir/58.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 57.93% confidence.
# Running prediction for: val_dir/59.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 85.82% confidence.
# Running prediction for: val_dir/60.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 63.60% confidence.
# Running prediction for: val_dir/61.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 62.25% confidence.
# Running prediction for: val_dir/62.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 68.37% confidence.
# Running prediction for: val_dir/63.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 79.09% confidence.
# Running prediction for: val_dir/64.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# This is a dog with 89.90% confidence.
# Running prediction for: val_dir/65.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 75.49% confidence.
# Running prediction for: val_dir/66.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 68.10% confidence.
# Running prediction for: val_dir/67.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 69.45% confidence.
# Running prediction for: val_dir/68.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 65.10% confidence.
# Running prediction for: val_dir/69.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 94.68% confidence.
# Running prediction for: val_dir/70.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 70.11% confidence.
# Running prediction for: val_dir/71.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 70.95% confidence.
# Running prediction for: val_dir/72.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 78.43% confidence.
# Running prediction for: val_dir/73.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 86.88% confidence.
# Running prediction for: val_dir/74.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 94.94% confidence.
# Running prediction for: val_dir/75.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 64.01% confidence.
# Running prediction for: val_dir/76.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 62.17% confidence.
# Running prediction for: val_dir/77.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 92.72% confidence.
# Running prediction for: val_dir/78.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 77.22% confidence.
# Running prediction for: val_dir/79.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 60.54% confidence.
# Running prediction for: val_dir/80.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 61.14% confidence.
# Running prediction for: val_dir/81.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 59.00% confidence.
# Running prediction for: val_dir/82.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 62.77% confidence.
# Running prediction for: val_dir/83.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 88.08% confidence.
# Running prediction for: val_dir/84.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 94.04% confidence.
# Running prediction for: val_dir/85.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 92.47% confidence.
# Running prediction for: val_dir/86.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 60.15% confidence.
# Running prediction for: val_dir/87.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 58.81% confidence.
# Running prediction for: val_dir/88.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 56.69% confidence.
# Running prediction for: val_dir/89.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 72.58% confidence.
# Running prediction for: val_dir/90.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 60.70% confidence.
# Running prediction for: val_dir/91.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 66.94% confidence.
# Running prediction for: val_dir/92.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 71.37% confidence.
# Running prediction for: val_dir/93.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 82.56% confidence.
# Running prediction for: val_dir/94.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 85.54% confidence.
# Running prediction for: val_dir/95.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 85.05% confidence.
# Running prediction for: val_dir/96.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 63.95% confidence.
# Running prediction for: val_dir/97.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 60.21% confidence.
# Running prediction for: val_dir/98.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 68.65% confidence.
# Running prediction for: val_dir/99.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 50.97% confidence.
# Running prediction for: val_dir/100.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 55.69% confidence.
# Running prediction for: val_dir/101.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 56.97% confidence.
# Running prediction for: val_dir/102.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 56.98% confidence.
# Running prediction for: val_dir/103.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 56.70% confidence.
# Running prediction for: val_dir/104.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 77.25% confidence.
# Running prediction for: val_dir/105.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 57.44% confidence.
# Running prediction for: val_dir/106.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 69.68% confidence.
# Running prediction for: val_dir/107.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 74.18% confidence.
# Running prediction for: val_dir/108.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 50.26% confidence.
# Running prediction for: val_dir/109.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 53.31% confidence.
# Running prediction for: val_dir/110.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 93.22% confidence.
# Running prediction for: val_dir/111.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 60.68% confidence.
# Running prediction for: val_dir/112.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 71.54% confidence.
# Running prediction for: val_dir/113.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# This is a dog with 91.86% confidence.
# Running prediction for: val_dir/114.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 76.75% confidence.
# Running prediction for: val_dir/115.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 71.72% confidence.
# Running prediction for: val_dir/116.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 87.69% confidence.
# Running prediction for: val_dir/117.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 71.13% confidence.
# Running prediction for: val_dir/118.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 56.36% confidence.
# Running prediction for: val_dir/119.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 52.74% confidence.
# Running prediction for: val_dir/120.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 54.03% confidence.
# Running prediction for: val_dir/121.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 54.22% confidence.
# Running prediction for: val_dir/122.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 82.99% confidence.
# Running prediction for: val_dir/123.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 59.00% confidence.
# Running prediction for: val_dir/124.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 77.77% confidence.
# Running prediction for: val_dir/125.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 64.38% confidence.
# Running prediction for: val_dir/126.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 62.43% confidence.
# Running prediction for: val_dir/127.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 82.37% confidence.
# Running prediction for: val_dir/128.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 67.88% confidence.
# Running prediction for: val_dir/129.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 61.00% confidence.
# Running prediction for: val_dir/130.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 81.47% confidence.
# Running prediction for: val_dir/131.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 90.54% confidence.
# Running prediction for: val_dir/132.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 68.03% confidence.
# Running prediction for: val_dir/133.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 61.05% confidence.
# Running prediction for: val_dir/134.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 62.83% confidence.
# Running prediction for: val_dir/135.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 58.82% confidence.
# Running prediction for: val_dir/136.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 80.38% confidence.
# Running prediction for: val_dir/137.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 65.42% confidence.
# Running prediction for: val_dir/138.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 59.98% confidence.
# Running prediction for: val_dir/139.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 60.29% confidence.
# Running prediction for: val_dir/140.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 76.20% confidence.
# Running prediction for: val_dir/141.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 66.24% confidence.
# Running prediction for: val_dir/142.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 63.06% confidence.
# Running prediction for: val_dir/143.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 96.94% confidence.
# Running prediction for: val_dir/144.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 79.83% confidence.
# Running prediction for: val_dir/145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 60.29% confidence.
# Running prediction for: val_dir/146.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 90.81% confidence.
# Running prediction for: val_dir/147.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 57.75% confidence.
# Running prediction for: val_dir/148.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 56.25% confidence.
# Running prediction for: val_dir/149.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 62.30% confidence.
# Running prediction for: val_dir/150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 54.35% confidence.
# Running prediction for: val_dir/151.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# This is a dog with 66.09% confidence.
# Running prediction for: val_dir/152.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 53.12% confidence.
# Running prediction for: val_dir/153.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 77.82% confidence.
# Running prediction for: val_dir/154.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 92.39% confidence.
# Running prediction for: val_dir/155.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 64.61% confidence.
# Running prediction for: val_dir/156.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 59.44% confidence.
# Running prediction for: val_dir/157.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 69.06% confidence.
# Running prediction for: val_dir/158.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 93.11% confidence.
# Running prediction for: val_dir/159.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 79.24% confidence.
# Running prediction for: val_dir/160.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 58.04% confidence.
# Running prediction for: val_dir/161.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 82.11% confidence.
# Running prediction for: val_dir/162.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 52.37% confidence.
# Running prediction for: val_dir/163.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 81.37% confidence.
# Running prediction for: val_dir/164.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 55.81% confidence.
# Running prediction for: val_dir/165.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 67.04% confidence.
# Running prediction for: val_dir/166.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 90.12% confidence.
# Running prediction for: val_dir/167.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 66.43% confidence.
# Running prediction for: val_dir/168.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 81.68% confidence.
# Running prediction for: val_dir/169.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 51.20% confidence.
# Running prediction for: val_dir/170.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 56.49% confidence.
# Running prediction for: val_dir/171.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 70.43% confidence.
# Running prediction for: val_dir/172.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 69.34% confidence.
# Running prediction for: val_dir/173.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 56.86% confidence.
# Running prediction for: val_dir/174.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 68.66% confidence.
# Running prediction for: val_dir/175.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 68.30% confidence.
# Running prediction for: val_dir/176.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 86.94% confidence.
# Running prediction for: val_dir/177.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 56.70% confidence.
# Running prediction for: val_dir/178.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 56.67% confidence.
# Running prediction for: val_dir/179.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 52.19% confidence.
# Running prediction for: val_dir/180.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 60.11% confidence.
# Running prediction for: val_dir/181.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 87.16% confidence.
# Running prediction for: val_dir/182.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# This is a dog with 80.41% confidence.
# Running prediction for: val_dir/183.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 62.20% confidence.
# Running prediction for: val_dir/184.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 64.16% confidence.
# Running prediction for: val_dir/185.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 73.51% confidence.
# Running prediction for: val_dir/186.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 75.04% confidence.
# Running prediction for: val_dir/187.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 59.05% confidence.
# Running prediction for: val_dir/188.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 81.59% confidence.
# Running prediction for: val_dir/189.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# This is a cat with 71.62% confidence.
# Running prediction for: val_dir/190.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 90.15% confidence.
# Running prediction for: val_dir/191.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 67.64% confidence.
# Running prediction for: val_dir/192.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 67.30% confidence.
# Running prediction for: val_dir/193.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 70.54% confidence.
# Running prediction for: val_dir/194.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 58.26% confidence.
# Running prediction for: val_dir/195.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 82.30% confidence.
# Running prediction for: val_dir/196.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 66.31% confidence.
# Running prediction for: val_dir/197.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 53.84% confidence.
# Running prediction for: val_dir/198.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 73.24% confidence.
# Running prediction for: val_dir/199.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 90.76% confidence.
# Running prediction for: val_dir/200.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 63.32% confidence.
# Running prediction for: val_dir/201.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 65.65% confidence.
# Running prediction for: val_dir/202.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 58.35% confidence.
# Running prediction for: val_dir/203.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 74.59% confidence.
# Running prediction for: val_dir/204.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 67.79% confidence.
# Running prediction for: val_dir/205.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 82.78% confidence.
# Running prediction for: val_dir/206.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 61.09% confidence.
# Running prediction for: val_dir/207.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 98.58% confidence.
# Running prediction for: val_dir/208.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 68.55% confidence.
# Running prediction for: val_dir/209.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 66.17% confidence.
# Running prediction for: val_dir/210.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 57.95% confidence.
# Running prediction for: val_dir/211.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 65.32% confidence.
# Running prediction for: val_dir/212.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 93.55% confidence.
# Running prediction for: val_dir/213.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 56.63% confidence.
# Running prediction for: val_dir/214.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 59.94% confidence.
# Running prediction for: val_dir/215.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 77.18% confidence.
# Running prediction for: val_dir/216.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 51.15% confidence.
# Running prediction for: val_dir/217.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 84.56% confidence.
# Running prediction for: val_dir/218.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 75.38% confidence.
# Running prediction for: val_dir/219.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 60.13% confidence.
# Running prediction for: val_dir/220.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 79.77% confidence.
# Running prediction for: val_dir/221.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 54.39% confidence.
# Running prediction for: val_dir/222.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 87.66% confidence.
# Running prediction for: val_dir/223.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 85.98% confidence.
# Running prediction for: val_dir/224.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 78.68% confidence.
# Running prediction for: val_dir/225.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 61.08% confidence.
# Running prediction for: val_dir/226.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 72.30% confidence.
# Running prediction for: val_dir/227.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 75.76% confidence.
# Running prediction for: val_dir/228.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 58.59% confidence.
# Running prediction for: val_dir/229.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 91
confidence.
# Running prediction for: val_dir/979.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 88.32% confidence.
# Running prediction for: val_dir/980.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 51.46% confidence.
# Running prediction for: val_dir/981.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 66.42% confidence.
# Running prediction for: val_dir/982.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 56.49% confidence.
# Running prediction for: val_dir/983.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# This is a dog with 72.79% confidence.
# Running prediction for: val_dir/984.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 89.08% confidence.
# Running prediction for: val_dir/985.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 73.34% confidence.
# Running prediction for: val_dir/986.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 72.26% confidence.
# Running prediction for: val_dir/987.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 63.02% confidence.
# Running prediction for: val_dir/988.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 84.26% confidence.
# Running prediction for: val_dir/989.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# This is a cat with 62.16% confidence.
# Running prediction for: val_dir/990.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 54.22% confidence.
# Running prediction for: val_dir/991.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# This is a cat with 71.22% confidence.
# Running prediction for: val_dir/992.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 57.04% confidence.
# Running prediction for: val_dir/993.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 50.99% confidence.
# Running prediction for: val_dir/994.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 72.32% confidence.
# Running prediction for: val_dir/995.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# This is a dog with 74.96% confidence.
# Running prediction for: val_dir/996.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 80.96% confidence.
# Running prediction for: val_dir/997.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# This is a dog with 79.85% confidence.
# Running prediction for: val_dir/998.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 60.19% confidence.
# Running prediction for: val_dir/999.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 65.16% confidence.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# Paths
train_dir = 'train/'

# Image preprocessing and augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,        # Random rotation between 0 and 40 degrees
    width_shift_range=0.2,    # Randomly shift images horizontally by 20%
    height_shift_range=0.2,   # Randomly shift images vertically by 20%
    shear_range=0.2,          # Random shear transformation
    zoom_range=0.2,           # Random zoom in/out
    horizontal_flip=True,     # Randomly flip images horizontally
    fill_mode='nearest'       # Fill in missing pixels after transformations
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)

# Model architecture
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=100,
    epochs=10,
    verbose=1
)

# Save the model after training
model.save('cats_and_dogs_classifier_data_augmentation.h5')  # This saves the model to a file

print("Model saved to 'cats_and_dogs_classifier_data_augmentation.h5'")
# Out:
# Found 25000 images belonging to 2 classes.
# /Users/anton/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# /Users/anton/Library/Python/3.9/lib/python/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 297ms/step - accuracy: 0.4929 - loss: 0.7061
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 267ms/step - accuracy: 0.5134 - loss: 0.6931
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 278ms/step - accuracy: 0.5299 - loss: 0.6905
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 283ms/step - accuracy: 0.5098 - loss: 0.6928
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 29s 286ms/step - accuracy: 0.5370 - loss: 0.6902
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 267ms/step - accuracy: 0.5519 - loss: 0.6840
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 29s 293ms/step - accuracy: 0.5550 - loss: 0.6808
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.5494 - loss: 0.6871
# Epoch 9/10
# 2024-10-01 13:31:27.172273: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:135: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(type, value, traceback)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 266ms/step - accuracy: 0.5454 - loss: 0.6842
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 266ms/step - accuracy: 0.5565 - loss: 0.6827
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to 'cats_and_dogs_classifier_data_augmentation.h5'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = tf.keras.models.load_model('cats_and_dogs_classifier_data_augmentation.h5')  # Replace with your model's path

# Load and preprocess the image
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(150, 150))  # Resize the image to the size the model expects
    img_array = image.img_to_array(img)  # Convert the image to a NumPy array
    img_array = np.expand_dims(img_array, axis=0)  # Add a batch dimension
    img_array /= 255.0  # Scale the pixel values to [0, 1]
    return img_array

# Function to predict whether the image is a cat or dog
def predict_image(img_path):
    img_array = preprocess_image(img_path)
    prediction = model.predict(img_array)  # Get the model's prediction
    confidence = float(prediction[0])  # Convert the NumPy array to a float

    if confidence > 0.5:
        print(f"This is a dog with {confidence * 100:.2f}% confidence.")
    else:
        print(f"This is a cat with {(1 - confidence) * 100:.2f}% confidence.")

# if True:
#     predict_image("/Users/anton/Downloads/download.jpeg")

if True:
    for i in range(1,1000):
        img_path = 'val_dir/' + str(i) + '.jpg'
        print("Running prediction for: " + img_path)
        predict_image(img_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Running prediction for: val_dir/1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# This is a dog with 51.40% confidence.
# Running prediction for: val_dir/2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 60.59% confidence.
# Running prediction for: val_dir/3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# /var/folders/qf/k0gw0vm95gb6q7gc15m75n_r0000gn/T/ipykernel_29676/631972757.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   confidence = float(prediction[0])  # Convert the NumPy array to a float
# This is a dog with 54.54% confidence.
# Running prediction for: val_dir/4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 99.95% confidence.
# Running prediction for: val_dir/5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 54.13% confidence.
# Running prediction for: val_dir/6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 58.18% confidence.
# Running prediction for: val_dir/7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 59.95% confidence.
# Running prediction for: val_dir/8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 50.03% confidence.
# Running prediction for: val_dir/9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 56.81% confidence.
# Running prediction for: val_dir/10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 52.31% confidence.
# Running prediction for: val_dir/11.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 53.14% confidence.
# Running prediction for: val_dir/12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 60.24% confidence.
# Running prediction for: val_dir/13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# This is a cat with 63.23% confidence.
# Running prediction for: val_dir/14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 50.45% confidence.
# Running prediction for: val_dir/15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 55.76% confidence.
# Running prediction for: val_dir/16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 58.04% confidence.
# Running prediction for: val_dir/17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 64.18% confidence.
# Running prediction for: val_dir/18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 91.73% confidence.
# Running prediction for: val_dir/19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a dog with 63.14% confidence.
# Running prediction for: val_dir/20.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 56.11% confidence.
# Running prediction for: val_dir/21.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 57.65% confidence.
# Running prediction for: val_dir/22.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 51.40% confidence.
# Running prediction for: val_dir/23.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 80.69% confidence.
# Running prediction for: val_dir/24.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a dog with 56.40% confidence.
# Running prediction for: val_dir/25.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 86.30% confidence.
# Running prediction for: val_dir/26.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 59.56% confidence.
# Running prediction for: val_dir/27.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 59.51% confidence.
# Running prediction for: val_dir/28.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 53.18% confidence.
# Running prediction for: val_dir/29.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 54.67% confidence.
# Running prediction for: val_dir/30.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 52.44% confidence.
# Running prediction for: val_dir/31.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 51.44% confidence.
# Running prediction for: val_dir/32.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 57.33% confidence.
# Running prediction for: val_dir/33.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 96.32% confidence.
# Running prediction for: val_dir/34.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 56.13% confidence.
# Running prediction for: val_dir/35.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 52.17% confidence.
# Running prediction for: val_dir/36.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 56.87% confidence.
# Running prediction for: val_dir/37.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 68.04% confidence.
# Running prediction for: val_dir/38.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 60.68% confidence.
# Running prediction for: val_dir/39.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 60.86% confidence.
# Running prediction for: val_dir/40.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 67.40% confidence.
# Running prediction for: val_dir/41.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 59.47% confidence.
# Running prediction for: val_dir/42.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 98.71% confidence.
# Running prediction for: val_dir/43.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 77.20% confidence.
# Running prediction for: val_dir/44.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 52.73% confidence.
# Running prediction for: val_dir/45.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 63.25% confidence.
# Running prediction for: val_dir/46.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 58.60% confidence.
# Running prediction for: val_dir/47.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 54.01% confidence.
# Running prediction for: val_dir/48.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 72.62% confidence.
# Running prediction for: val_dir/49.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 63.32% confidence.
# Running prediction for: val_dir/50.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 51.27% confidence.
# Running prediction for: val_dir/51.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 90.23% confidence.
# Running prediction for: val_dir/52.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 52.50% confidence.
# Running prediction for: val_dir/53.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 63.34% confidence.
# Running prediction for: val_dir/54.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 57.22% confidence.
# Running prediction for: val_dir/55.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 50.43% confidence.
# Running prediction for: val_dir/56.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 73.49% confidence.
# Running prediction for: val_dir/57.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 65.28% confidence.
# Running prediction for: val_dir/58.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 58.16% confidence.
# Running prediction for: val_dir/59.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 65.87% confidence.
# Running prediction for: val_dir/60.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 86.16% confidence.
# Running prediction for: val_dir/61.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 52.67% confidence.
# Running prediction for: val_dir/62.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 61.55% confidence.
# Running prediction for: val_dir/63.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 63.61% confidence.
# Running prediction for: val_dir/64.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 89.40% confidence.
# Running prediction for: val_dir/65.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 99.16% confidence.
# Running prediction for: val_dir/66.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 66.25% confidence.
# Running prediction for: val_dir/67.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 69.28% confidence.
# Running prediction for: val_dir/68.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 57.01% confidence.
# Running prediction for: val_dir/69.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 94.32% confidence.
# Running prediction for: val_dir/70.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 50.51% confidence.
# Running prediction for: val_dir/71.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 50.42% confidence.
# Running prediction for: val_dir/72.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 65.00% confidence.
# Running prediction for: val_dir/73.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a dog with 68.97% confidence.
# Running prediction for: val_dir/74.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 97.99% confidence.
# Running prediction for: val_dir/75.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 55.99% confidence.
# Running prediction for: val_dir/76.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 55.45% confidence.
# Running prediction for: val_dir/77.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 72.92% confidence.
# Running prediction for: val_dir/78.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 61.43% confidence.
# Running prediction for: val_dir/79.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 63.67% confidence.
# Running prediction for: val_dir/80.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 65.85% confidence.
# Running prediction for: val_dir/81.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 51.42% confidence.
# Running prediction for: val_dir/82.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 51.68% confidence.
# Running prediction for: val_dir/83.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 54.86% confidence.
# Running prediction for: val_dir/84.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 50.92% confidence.
# Running prediction for: val_dir/85.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 76.05% confidence.
# Running prediction for: val_dir/86.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 73.18% confidence.
# Running prediction for: val_dir/87.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 52.92% confidence.
# Running prediction for: val_dir/88.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 53.02% confidence.
# Running prediction for: val_dir/89.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 88.01% confidence.
# Running prediction for: val_dir/90.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 67.40% confidence.
# Running prediction for: val_dir/91.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 87.67% confidence.
# Running prediction for: val_dir/92.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 77.43% confidence.
# Running prediction for: val_dir/93.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 63.72% confidence.
# Running prediction for: val_dir/94.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 99.48% confidence.
# Running prediction for: val_dir/95.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 98.19% confidence.
# Running prediction for: val_dir/96.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 59.93% confidence.
# Running prediction for: val_dir/97.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 52.34% confidence.
# Running prediction for: val_dir/98.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 68.23% confidence.
# Running prediction for: val_dir/99.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 62.76% confidence.
# Running prediction for: val_dir/100.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 51.11% confidence.
# Running prediction for: val_dir/101.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 69.14% confidence.
# Running prediction for: val_dir/102.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 53.49% confidence.
# Running prediction for: val_dir/103.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 64.92% confidence.
# Running prediction for: val_dir/104.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 61.04% confidence.
# Running prediction for: val_dir/105.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 53.05% confidence.
# Running prediction for: val_dir/106.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 60.58% confidence.
# Running prediction for: val_dir/107.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a cat with 60.89% confidence.
# Running prediction for: val_dir/108.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 51.75% confidence.
# Running prediction for: val_dir/109.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 98.35% confidence.
# Running prediction for: val_dir/110.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 84.78% confidence.
# Running prediction for: val_dir/111.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 75.00% confidence.
# Running prediction for: val_dir/112.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 51.90% confidence.
# Running prediction for: val_dir/113.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 90.31% confidence.
# Running prediction for: val_dir/114.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 53.88% confidence.
# Running prediction for: val_dir/115.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 91.22% confidence.
# Running prediction for: val_dir/116.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 51.41% confidence.
# Running prediction for: val_dir/117.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 79.06% confidence.
# Running prediction for: val_dir/118.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 62.83% confidence.
# Running prediction for: val_dir/119.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 61.70% confidence.
# Running prediction for: val_dir/120.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 56.39% confidence.
# Running prediction for: val_dir/121.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 66.43% confidence.
# Running prediction for: val_dir/122.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 56.87% confidence.
# Running prediction for: val_dir/123.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 52.65% confidence.
# Running prediction for: val_dir/124.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 51.31% confidence.
# Running prediction for: val_dir/125.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 72.94% confidence.
# Running prediction for: val_dir/126.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a dog with 77.34% confidence.
# Running prediction for: val_dir/127.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 60.71% confidence.
# Running prediction for: val_dir/128.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 61.64% confidence.
# Running prediction for: val_dir/129.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 56.63% confidence.
# Running prediction for: val_dir/130.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 55.58% confidence.
# Running prediction for: val_dir/131.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# This is a dog with 99.05% confidence.
# Running prediction for: val_dir/132.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# This is a dog with 54.71% confidence.
# Running prediction for: val_dir/133.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# This is a dog with 58.97% confidence.
# Running prediction for: val_dir/134.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 58.22% confidence.
# Running prediction for: val_dir/135.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 54.19% confidence.
# Running prediction for: val_dir/136.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 61.01% confidence.
# Running prediction for: val_dir/137.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 83.40% confidence.
# Running prediction for: val_dir/138.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 53.60% confidence.
# Running prediction for: val_dir/139.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 72.78% confidence.
# Running prediction for: val_dir/140.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 51.74% confidence.
# Running prediction for: val_dir/141.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 50.93% confidence.
# Running prediction for: val_dir/142.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 68.03% confidence.
# Running prediction for: val_dir/143.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 87.10% confidence.
# Running prediction for: val_dir/144.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a dog with 57.14% confidence.
# Running prediction for: val_dir/145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 58.41% confidence.
# Running prediction for: val_dir/146.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a dog with 87.91% confidence.
# Running prediction for: val_dir/147.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 56.99% confidence.
# Running prediction for: val_dir/148.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a cat with 50.88% confidence.
# Running prediction for: val_dir/149.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a cat with 57.00% confidence.
# Running prediction for: val_dir/150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 51.81% confidence.
# Running prediction for: val_dir/151.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 60.27% confidence.
# Running prediction for: val_dir/152.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 67.90% confidence.
# Running prediction for: val_dir/153.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# This is a dog with 94.37% confidence.
# Running prediction for: val_dir/154.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 63.95% confidence.
# Running prediction for: val_dir/155.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 62.38% confidence.
# Running prediction for: val_dir/156.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 75.64% confidence.
# Running prediction for: val_dir/157.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 59.11% confidence.
# Running prediction for: val_dir/158.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 60.14% confidence.
# Running prediction for: val_dir/159.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 56.70% confidence.
# Running prediction for: val_dir/160.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 54.23% confidence.
# Running prediction for: val_dir/161.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 61.47% confidence.
# Running prediction for: val_dir/162.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 59.83% confidence.
# Running prediction for: val_dir/163.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 51.81% confidence.
# Running prediction for: val_dir/164.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 60.17% confidence.
# Running prediction for: val_dir/165.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 54.19% confidence.
# Running prediction for: val_dir/166.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 56.27% confidence.
# Running prediction for: val_dir/167.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 51.14% confidence.
# Running prediction for: val_dir/168.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 54.86% confidence.
# Running prediction for: val_dir/169.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a dog with 52.77% confidence.
# Running prediction for: val_dir/170.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 51.59% confidence.
# Running prediction for: val_dir/171.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 50.68% confidence.
# Running prediction for: val_dir/172.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 52.90% confidence.
# Running prediction for: val_dir/173.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 50.72% confidence.
# Running prediction for: val_dir/174.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 65.29% confidence.
# Running prediction for: val_dir/175.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 67.21% confidence.
# Running prediction for: val_dir/176.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 85.70% confidence.
# Running prediction for: val_dir/177.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# This is a dog with 57.10% confidence.
# Running prediction for: val_dir/178.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 78.46% confidence.
# Running prediction for: val_dir/179.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# This is a cat with 50.47% confidence.
# Running prediction for: val_dir/180.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 68.97% confidence.
# Running prediction for: val_dir/181.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 93.38% confidence.
# Running prediction for: val_dir/182.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 63.63% confidence.
# Running prediction for: val_dir/183.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 56.37% confidence.
# Running prediction for: val_dir/184.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 53.24% confidence.
# Running prediction for: val_dir/185.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 50.39% confidence.
# Running prediction for: val_dir/186.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 68.80% confidence.
# Running prediction for: val_dir/187.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 57.03% confidence.
# Running prediction for: val_dir/188.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 52.08% confidence.
# Running prediction for: val_dir/189.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 66.56% confidence.
# Running prediction for: val_dir/190.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 87.42% confidence.
# Running prediction for: val_dir/191.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 71.62% confidence.
# Running prediction for: val_dir/192.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 58.87% confidence.
# Running prediction for: val_dir/193.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 55.99% confidence.
# Running prediction for: val_dir/194.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 60.70% confidence.
# Running prediction for: val_dir/195.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 92.01% confidence.
# Running prediction for: val_dir/196.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 53.60% confidence.
# Running prediction for: val_dir/197.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 51
confidence.
# Running prediction for: val_dir/954.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 54.02% confidence.
# Running prediction for: val_dir/955.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# This is a dog with 96.95% confidence.
# Running prediction for: val_dir/956.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 59.64% confidence.
# Running prediction for: val_dir/957.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 63.54% confidence.
# Running prediction for: val_dir/958.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 94.72% confidence.
# Running prediction for: val_dir/959.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 55.66% confidence.
# Running prediction for: val_dir/960.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 50.45% confidence.
# Running prediction for: val_dir/961.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 68.27% confidence.
# Running prediction for: val_dir/962.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# This is a dog with 67.32% confidence.
# Running prediction for: val_dir/963.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# This is a dog with 58.27% confidence.
# Running prediction for: val_dir/964.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 51.95% confidence.
# Running prediction for: val_dir/965.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a cat with 50.69% confidence.
# Running prediction for: val_dir/966.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# This is a dog with 63.10% confidence.
# Running prediction for: val_dir/967.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# This is a dog with 69.18% confidence.
# Running prediction for: val_dir/968.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 51.00% confidence.
# Running prediction for: val_dir/969.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a dog with 58.06% confidence.
# Running prediction for: val_dir/970.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 95.50% confidence.
# Running prediction for: val_dir/971.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 52.19% confidence.
# Running prediction for: val_dir/972.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 51.05% confidence.
# Running prediction for: val_dir/973.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 82.74% confidence.
# Running prediction for: val_dir/974.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 58.91% confidence.
# Running prediction for: val_dir/975.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# This is a dog with 55.85% confidence.
# Running prediction for: val_dir/976.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# This is a dog with 57.86% confidence.
# Running prediction for: val_dir/977.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 52.01% confidence.
# Running prediction for: val_dir/978.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a cat with 54.46% confidence.
# Running prediction for: val_dir/979.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 99.53% confidence.
# Running prediction for: val_dir/980.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 69.06% confidence.
# Running prediction for: val_dir/981.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 92.00% confidence.
# Running prediction for: val_dir/982.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 57.72% confidence.
# Running prediction for: val_dir/983.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# This is a dog with 53.06% confidence.
# Running prediction for: val_dir/984.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 82.77% confidence.
# Running prediction for: val_dir/985.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a cat with 64.27% confidence.
# Running prediction for: val_dir/986.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# This is a dog with 56.83% confidence.
# Running prediction for: val_dir/987.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This is a cat with 55.35% confidence.
# Running prediction for: val_dir/988.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 53.01% confidence.
# Running prediction for: val_dir/989.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# This is a dog with 56.34% confidence.
# Running prediction for: val_dir/990.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a cat with 62.12% confidence.
# Running prediction for: val_dir/991.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 51.90% confidence.
# Running prediction for: val_dir/992.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 51.69% confidence.
# Running prediction for: val_dir/993.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 55.44% confidence.
# Running prediction for: val_dir/994.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 74.83% confidence.
# Running prediction for: val_dir/995.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# This is a dog with 61.98% confidence.
# Running prediction for: val_dir/996.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 57.82% confidence.
# Running prediction for: val_dir/997.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This is a dog with 81.86% confidence.
# Running prediction for: val_dir/998.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This is a dog with 56.05% confidence.
# Running prediction for: val_dir/999.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a dog with 62.22% confidence.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# Paths
train_dir = 'train/'

# Image preprocessing and augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,        # Random rotation between 0 and 40 degrees
    width_shift_range=0.2,    # Randomly shift images horizontally by 20%
    height_shift_range=0.2,   # Randomly shift images vertically by 20%
    shear_range=0.2,          # Random shear transformation
    zoom_range=0.2,           # Random zoom in/out
    horizontal_flip=True,     # Randomly flip images horizontally
    fill_mode='nearest'       # Fill in missing pixels after transformations
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)

# Model architecture
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(256, (3, 3), activation='relu'))  # Add more filters
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))  # Add dropout to prevent overfitting
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=100,
    epochs=10,
    verbose=1
)

# Save the model after training
model.save('cats_and_dogs_classifier_model_layering.h5')  # This saves the model to a file

print("Model saved to 'cats_and_dogs_classifier_model_layering.h5'")
# Out:
# Found 25000 images belonging to 2 classes.
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 33s 312ms/step - accuracy: 0.5302 - loss: 0.7213
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 312ms/step - accuracy: 0.5270 - loss: 0.6915
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 314ms/step - accuracy: 0.5541 - loss: 0.6834
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 307ms/step - accuracy: 0.5820 - loss: 0.6701
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 310ms/step - accuracy: 0.5208 - loss: 0.6973
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 312ms/step - accuracy: 0.5622 - loss: 0.6802
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 30s 303ms/step - accuracy: 0.5769 - loss: 0.6748
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 248ms/step - accuracy: 0.5917 - loss: 0.6739
# Epoch 9/10
# 2024-10-01 13:49:02.957849: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 303ms/step - accuracy: 0.6078 - loss: 0.6604
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 305ms/step - accuracy: 0.5950 - loss: 0.6698
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to 'cats_and_dogs_classifier_model_layering.h5'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = tf.keras.models.load_model('cats_and_dogs_classifier_model_layering.h5')  # Replace with your model's path

# Load and preprocess the image
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(150, 150))  # Resize the image to the size the model expects
    img_array = image.img_to_array(img)  # Convert the image to a NumPy array
    img_array = np.expand_dims(img_array, axis=0)  # Add a batch dimension
    img_array /= 255.0  # Scale the pixel values to [0, 1]
    return img_array

# Function to predict whether the image is a cat or dog
def predict_image(img_path):
    img_array = preprocess_image(img_path)
    prediction = model.predict(img_array)  # Get the model's prediction
    confidence = float(prediction[0])  # Convert the NumPy array to a float

    if confidence > 0.5:
        print(f"This is a dog with {confidence * 100:.2f}% confidence.")
    else:
        print(f"This is a cat with {(1 - confidence) * 100:.2f}% confidence.")

# if True:
#     predict_image("/Users/anton/Downloads/download.jpeg")

if True:
    for i in range(1,1000):
        img_path = 'val_dir/' + str(i) + '.jpg'
        print("Running prediction for: " + img_path)
        predict_image(img_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 6
#       3 import numpy as np
#       5 # Load the trained model
# ----> 6 model = tf.keras.models.load_model('cats_and_dogs_classifier_model_layering.h5')  # Replace with your model's path
#       8 # Load and preprocess the image
#       9 def preprocess_image(img_path):
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/saving/saving_api.py:194, in load_model(filepath, custom_objects, compile, safe_mode)
#     187     return saving_lib.load_model(
#     188         filepath,
#     189         custom_objects=custom_objects,
#     190         compile=compile,
#     191         safe_mode=safe_mode,
#     192     )
#     193 if str(filepath).endswith((".h5", ".hdf5")):
# --> 194     return legacy_h5_format.load_model_from_hdf5(
#     195         filepath, custom_objects=custom_objects, compile=compile
#     196     )
#     197 elif str(filepath).endswith(".keras"):
#     198     raise ValueError(
#     199         f"File not found: filepath={filepath}. "
#     200         "Please ensure the file is an accessible `.keras` "
#     201         "zip file."
#     202     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/legacy/saving/legacy_h5_format.py:116, in load_model_from_hdf5(filepath, custom_objects, compile)
#     114 opened_new_file = not isinstance(filepath, h5py.File)
#     115 if opened_new_file:
# --> 116     f = h5py.File(filepath, mode="r")
#     117 else:
#     118     f = filepath
#
# File ~/Library/Python/3.9/lib/python/site-packages/h5py/_hl/files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File ~/Library/Python/3.9/lib/python/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = 'cats_and_dogs_classifier_model_layering.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
